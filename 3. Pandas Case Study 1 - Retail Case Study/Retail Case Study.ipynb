# %%
import pandas as pd

# %%
cust=pd.read_csv("D:/Analytixlabs Data/Module 5 - Python Foundation/Case Studies/3. Pandas Case Study 1 - Retail Case Study/Customer.csv")

# %%
prod=pd.read_csv("D:/Analytixlabs Data/Module 5 - Python Foundation/Case Studies/3. Pandas Case Study 1 - Retail Case Study/prod_cat_info.csv")

# %%
trans=pd.read_csv("D:/Analytixlabs Data/Module 5 - Python Foundation/Case Studies/3. Pandas Case Study 1 - Retail Case Study/Transactions.csv")

# %% [markdown]
# # 1.Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to keep all customers who have done transactions with us and select the join type accordingly

# %%
cust.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
prod.head()
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %%
trans.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
Customer_Final=pd.merge(how="left",left=trans,right=cust,left_on="cust_id",right_on='customer_Id')

# %%
Customer_Final.shape
# Out:
# (23053, 14)

# %%
trans.shape
# Out:
# (23053, 10)

# %%
Customer_Final.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type  customer_Id         DOB Gender  \
# 0  -772  405.300  -4265.300     e-Shop       270351  26-09-1981      M
# 1 -1497  785.925  -8270.925     e-Shop       270384  11-05-1973      F
# 2  -791  166.110  -1748.110   TeleShop       273420  27-07-1992      M
# 3 -1363  429.345  -4518.345     e-Shop       271509  08-06-1981      M
# 4  -791  166.110  -1748.110   TeleShop       273420  27-07-1992      M
#
#    city_code
# 0        5.0
# 1        8.0
# 2        8.0
# 3        3.0
# ...

# %%
prod.head()
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %%
Customer_Final=pd.merge(how="left",left=Customer_Final,right=prod,left_on=["prod_cat_code",'prod_subcat_code'],right_on=["prod_cat_code","prod_sub_cat_code"])

# %%
Customer_Final.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type  customer_Id         DOB Gender  \
# 0  -772  405.300  -4265.300     e-Shop       270351  26-09-1981      M
# 1 -1497  785.925  -8270.925     e-Shop       270384  11-05-1973      F
# 2  -791  166.110  -1748.110   TeleShop       273420  27-07-1992      M
# 3 -1363  429.345  -4518.345     e-Shop       271509  08-06-1981      M
# 4  -791  166.110  -1748.110   TeleShop       273420  27-07-1992      M
#
#    city_code          prod_cat  prod_sub_cat_code prod_subcat
# ...

# %%
Customer_Final.shape
# Out:
# (23053, 17)

# %% [markdown]
# # 2. Prepare a summary report for the merged data set.
# ## a. Get the column names and their corresponding data types
# ## b. Top/Bottom 10 observations
# ## c.  “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)
# ## d. Frequency tables for all the categorical variables

# %%
Customer_Final.dtypes
# Out:
# transaction_id         int64
# cust_id                int64
# tran_date             object
# prod_subcat_code       int64
# prod_cat_code          int64
# Qty                    int64
# Rate                   int64
# Tax                  float64
# total_amt            float64
# Store_type            object
# customer_Id            int64
# DOB                   object
# Gender                object
# city_code            float64
# prod_cat              object
# prod_sub_cat_code      int64
# prod_subcat           object
# dtype: object

# %%
Customer_Final.head(10)
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
# 5     97439039119   272357  23-02-2014                 8              3   -2
# 6     45649838090   273667  22-02-2014                11              6   -1
# 7     22643667930   271489  22-02-2014                12              6   -1
# 8     79792372943   275108  22-02-2014                 3              1   -3
# 9     50076728598   269014  21-02-2014                 8              3   -4
#
#    Rate      Tax  total_amt Store_type  customer_Id         DOB Gender  \
# ...

# %%
Customer_Final.tail(10)
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 23043     49882891062   271982  25-01-2011                10              5
# 23044     14787475597   273982  25-01-2011                 4              3
# 23045     50691119572   273031  25-01-2011                 6              5
# 23046     40893803228   272049  25-01-2011                11              6
# 23047     30856003613   266866  25-01-2011                 4              2
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type  customer_Id         DOB  \
# ...

# %%
Customer_Final.describe()
# Out:
#        transaction_id        cust_id  prod_subcat_code  prod_cat_code  \
# count    2.305300e+04   23053.000000      23053.000000   23053.000000
# mean     5.007348e+10  271021.746497          6.149091       3.763632
# std      2.898194e+10    2431.692059          3.726372       1.677016
# min      3.268991e+06  266783.000000          1.000000       1.000000
# 25%      2.493864e+10  268935.000000          3.000000       2.000000
# 50%      5.009313e+10  270980.000000          5.000000       4.000000
# 75%      7.533000e+10  273114.000000         10.000000       5.000000
# max      9.998755e+10  275265.000000         12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt    customer_Id  \
# count  23053.000000  23053.000000  23053.000000  23053.000000   23053.000000
# mean       2.432395    636.369713    248.667192   2107.308002  271021.746497
# std        2.268406    622.363498    187.177773   2507.561264    2431.692059
# ...

# %%
for i in list(Customer_Final.dtypes[Customer_Final.dtypes=='object'].index):
    print(Customer_Final[i].value_counts())
# Out:
# 13-07-2011    35
# 22-11-2011    33
# 25-09-2011    33
# 21-12-2013    33
# 23-10-2011    33
#               ..
# 23-02-2014     2
# 24-02-2014     2
# 28-02-2014     1
# 21-02-2014     1
# 27-02-2014     1
# Name: tran_date, Length: 1129, dtype: int64
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: Store_type, dtype: int64
# 17-09-1982    32
# 27-12-1988    32
# 25-02-1974    27
# 20-03-1972    25
# 09-06-1970    24
#               ..
# 16-07-1974     1
# 14-07-1979     1
# 29-07-1991     1
# 15-10-1975     1
# 16-05-1982     1
# Name: DOB, Length: 3987, dtype: int64
# M    11811
# F    11233
# Name: Gender, dtype: int64
# Books               6069
# Electronics         4898
# Home and kitchen    4129
# Footwear            2999
# Clothing            2960
# Bags                1998
# Name: prod_cat, dtype: int64
# Women                  3048
# Mens                   2912
# Kids                   1997
# ...

# %% [markdown]
# # 3. Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
Customer_Final['transaction_id']=Customer_Final['transaction_id'].astype(dtype="object")
Customer_Final['cust_id']=Customer_Final['transaction_id'].astype(dtype="object")

# %%
Customer_Final['tran_date']=pd.to_datetime(Customer_Final['tran_date'])

# %%
Customer_Final.drop('customer_Id',axis=1,inplace=True)

# %%
Customer_Final['DOB']=pd.to_datetime(Customer_Final['DOB'])

# %%
Customer_Final.drop('prod_sub_cat_code',axis=1,inplace=True)

# %%
Customer_Final.dtypes
# Out:
# transaction_id              object
# cust_id                     object
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# prod_cat                    object
# prod_subcat                 object
# dtype: object

# %%
Customer_Final.dtypes[Customer_Final.dtypes=='object'].index
# Out:
# Index(['transaction_id', 'cust_id', 'Store_type', 'Gender', 'prod_cat',
#        'prod_subcat'],
#       dtype='object')

# %%
Customer_Final.dtypes[Customer_Final.dtypes=='int64'].index
# Out:
# Index(['prod_subcat_code', 'prod_cat_code', 'Qty', 'Rate'], dtype='object')

# %%
Customer_Final.duplicated().sum()
# Out:
# 13

# %%
Customer_Final.drop_duplicates(inplace=True)

# %%
Customer_Final.duplicated().sum()
# Out:
# 0

# %%
conti_customer = Customer_Final.loc[:,['prod_subcat_code','prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt']]

# %%
conti_customer
# Out:
#        prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt
# 0                     1              1   -5  -772  405.300  -4265.300
# 1                     5              3   -5 -1497  785.925  -8270.925
# 2                     6              5   -2  -791  166.110  -1748.110
# 3                    11              6   -3 -1363  429.345  -4518.345
# 4                     6              5   -2  -791  166.110  -1748.110
# ...                 ...            ...  ...   ...      ...        ...
# 23048                12              5    1  1264  132.720   1396.720
# 23049                 4              1    1   677   71.085    748.085
# 23050                 2              6    4  1052  441.840   4649.840
# 23051                11              5    3  1142  359.730   3785.730
# 23052                11              5    1   447   46.935    493.935
#
# [23040 rows x 6 columns]

# %%
for var in conti_customer.columns:
    conti_customer[var].plot(kind='hist')
    plt.title(var)
    plt.show()

# %%
category_customer = Customer_Final.loc[:,Customer_Final.dtypes=='object']

# %%
category_customer
# Out:
#       transaction_id      cust_id Store_type Gender          prod_cat  \
# 0        80712190438  80712190438     e-Shop      M          Clothing
# 1        29258453508  29258453508     e-Shop      F       Electronics
# 2        51750724947  51750724947   TeleShop      M             Books
# 3        93274880719  93274880719     e-Shop      M  Home and kitchen
# 4        51750724947  51750724947   TeleShop      M             Books
# ...              ...          ...        ...    ...               ...
# 23048    94340757522  94340757522     e-Shop      M             Books
# 23049    89780862956  89780862956     e-Shop      M          Clothing
# 23050    85115299378  85115299378        MBR      M  Home and kitchen
# 23051    72870271171  72870271171   TeleShop      M             Books
# 23052    77960931771  77960931771   TeleShop      M             Books
#
#       prod_subcat
# 0           Women
# 1       Computers
# 2             DIY
# 3            Bath
# 4             DIY
# ...

# %%
sns.countplot(category_customer['Gender'])
plt.show()

# %%
sns.countplot(category_customer['Store_type'])
plt.xlabel('Store Type')
plt.show()

# %%
sns.countplot(category_customer['prod_cat'])
plt.xlabel('Product Category')
plt.show()

# %%
plt.figure(figsize=(22,8))
sns.countplot(category_customer['prod_subcat'])
plt.xlabel('Product Sub Category')
plt.show()

# %% [markdown]
# # 4. Calculate the following information using the merged dataset :
# ## a. Time period of the available transaction data
# ## b. Count of transactions where the total amount of transaction was negative

# %%
Customer_Final.tran_date.max()
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
Customer_Final.tran_date.min()
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
number_of_days=Customer_Final.tran_date.max()-Customer_Final.tran_date.min()

# %%
number_of_days.days
# Out:
# 1430

# %%
Customer_Final[Customer_Final.total_amt<0]['total_amt'].count()
# Out:
# 2164

# %% [markdown]
# # 5. Analyze which product categories are more popular among females vs male customers.

# %%
Customer_Final.head()
# Out:
#   transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0    80712190438  80712190438 2014-02-28                 1              1
# 1    29258453508  29258453508 2014-02-27                 5              3
# 2    51750724947  51750724947 2014-02-24                 6              5
# 3    93274880719  93274880719 2014-02-24                11              6
# 4    51750724947  51750724947 2014-02-23                 6              5
#
#    Qty  Rate      Tax  total_amt Store_type        DOB Gender  city_code  \
# 0   -5  -772  405.300  -4265.300     e-Shop 1981-09-26      M        5.0
# 1   -5 -1497  785.925  -8270.925     e-Shop 1973-11-05      F        8.0
# 2   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
# 3   -3 -1363  429.345  -4518.345     e-Shop 1981-08-06      M        3.0
# 4   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
#
#            prod_cat prod_subcat
# 0          Clothing       Women
# ...

# %%
Customer_Final.groupby(by=["Gender","prod_cat"])["Qty"].sum().reset_index()
# Out:
#    Gender          prod_cat   Qty
# 0       F              Bags  2364
# 1       F             Books  7080
# 2       F          Clothing  3425
# 3       F       Electronics  5832
# 4       F          Footwear  3721
# 5       F  Home and kitchen  4898
# 6       M              Bags  2346
# 7       M             Books  7587
# 8       M          Clothing  3748
# 9       M       Electronics  6486
# 10      M          Footwear  3561
# 11      M  Home and kitchen  5051

# %% [markdown]
# # 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
city_group=Customer_Final.groupby(by='city_code')['city_code'].count().sort_values(ascending=False)

# %%
city_group
# Out:
# city_code
# 4.0     2422
# 3.0     2410
# 5.0     2357
# 7.0     2356
# 10.0    2333
# 8.0     2328
# 2.0     2268
# 1.0     2255
# 9.0     2176
# 6.0     2127
# Name: city_code, dtype: int64

# %%
percentage=(city_group[4.0]/city_group.sum())*100

# %%
print("City code 4.0 has the maximum customers and the percentage of customers from that city is ",percentage)
# Out:
# City code 4.0 has the maximum customers and the percentage of customers from that city is  10.515804098645363

# %% [markdown]
# ## 7. Which store type sells the maximum products by value and by quantity?

# %%
Customer_Final.head(2)
# Out:
#   transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0    80712190438  80712190438 2014-02-28                 1              1
# 1    29258453508  29258453508 2014-02-27                 5              3
#
#    Qty  Rate      Tax  total_amt Store_type        DOB Gender  city_code  \
# 0   -5  -772  405.300  -4265.300     e-Shop 1981-09-26      M        5.0
# 1   -5 -1497  785.925  -8270.925     e-Shop 1973-11-05      F        8.0
#
#       prod_cat prod_subcat
# 0     Clothing       Women
# 1  Electronics   Computers

# %%
Customer_Final.groupby(by='Store_type')['Rate','Qty'].sum().sort_values(by="Qty",ascending=False)
# Out:
# <ipython-input-183-b6d8f0671581>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Customer_Final.groupby(by='Store_type')['Rate','Qty'].sum().sort_values(by="Qty",ascending=False)
#                    Rate    Qty
# Store_type
# e-Shop          5945770  22790
# MBR             2953665  11195
# Flagship store  2942874  11142
# TeleShop        2836359  10993

# %% [markdown]
# ## 8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
store_group=Customer_Final.groupby(by=['Store_type','prod_cat'])['total_amt'].sum()

# %%
store_group['Flagship store'][["Electronics","Clothing"]]
# Out:
# prod_cat
# Electronics    2215136.04
# Clothing       1194423.23
# Name: total_amt, dtype: float64

# %% [markdown]
# ## 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
gender_prodcat_grp=Customer_Final.groupby(by=["Gender",'prod_cat'])['total_amt'].sum()

# %%
gender_prodcat_grp['M']['Electronics']
# Out:
# 5711351.62000002

# %% [markdown]
# ## 10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
Customer_Final.head()
# Out:
#   transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0    80712190438  80712190438 2014-02-28                 1              1
# 1    29258453508  29258453508 2014-02-27                 5              3
# 2    51750724947  51750724947 2014-02-24                 6              5
# 3    93274880719  93274880719 2014-02-24                11              6
# 4    51750724947  51750724947 2014-02-23                 6              5
#
#    Qty  Rate      Tax  total_amt Store_type        DOB Gender  city_code  \
# 0   -5  -772  405.300  -4265.300     e-Shop 1981-09-26      M        5.0
# 1   -5 -1497  785.925  -8270.925     e-Shop 1973-11-05      F        8.0
# 2   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
# 3   -3 -1363  429.345  -4518.345     e-Shop 1981-08-06      M        3.0
# 4   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
#
#            prod_cat prod_subcat
# 0          Clothing       Women
# ...

# %%
non_neg_trans=Customer_Final[Customer_Final.total_amt>0]

# %%
non_neg_trans.groupby(by='cust_id')['transaction_id'].count()
# Out:
# cust_id
# 3268991        1
# 7073244        1
# 10861359       1
# 15741026       1
# 16165359       1
#               ..
# 99963516507    1
# 99967775192    1
# 99985121471    1
# 99986751618    1
# 99987549630    1
# Name: transaction_id, Length: 20876, dtype: int64

# %%
non_neg_trans['cust_id'].value_counts().sum()
# Out:
# 20876

# %%
print("All custids are unique and therefore all the transaction are unique")
# Out:
# All custids are unique and therefore all the transaction are unique

# %% [markdown]
# # 11. For all customers aged between 25 - 35, find out:
# ### a. What was the total amount spent for “Electronics” and “Books” product categories?
# ### b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
Customer_Final.head()
# Out:
#   transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0    80712190438  80712190438 2014-02-28                 1              1
# 1    29258453508  29258453508 2014-02-27                 5              3
# 2    51750724947  51750724947 2014-02-24                 6              5
# 3    93274880719  93274880719 2014-02-24                11              6
# 4    51750724947  51750724947 2014-02-23                 6              5
#
#    Qty  Rate      Tax  total_amt Store_type        DOB Gender  city_code  \
# 0   -5  -772  405.300  -4265.300     e-Shop 1981-09-26      M        5.0
# 1   -5 -1497  785.925  -8270.925     e-Shop 1973-11-05      F        8.0
# 2   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
# 3   -3 -1363  429.345  -4518.345     e-Shop 1981-08-06      M        3.0
# 4   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
#
#            prod_cat prod_subcat
# 0          Clothing       Women
# ...

# %%
now = pd.Timestamp('now')

# %%
Customer_Final['Current Date']=now

# %%
Customer_Final
# Out:
#       transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0        80712190438  80712190438 2014-02-28                 1              1
# 1        29258453508  29258453508 2014-02-27                 5              3
# 2        51750724947  51750724947 2014-02-24                 6              5
# 3        93274880719  93274880719 2014-02-24                11              6
# 4        51750724947  51750724947 2014-02-23                 6              5
# ...              ...          ...        ...               ...            ...
# 23048    94340757522  94340757522 2011-01-25                12              5
# 23049    89780862956  89780862956 2011-01-25                 4              1
# 23050    85115299378  85115299378 2011-01-25                 2              6
# 23051    72870271171  72870271171 2011-01-25                11              5
# 23052    77960931771  77960931771 2011-01-25                11              5
#
# ...

# %%
Customer_Final['age']=(Customer_Final['Current Date']-Customer_Final['DOB']).astype('<m8[Y]')

# %%
Customer_Final.head()
# Out:
#   transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 0    80712190438  80712190438 2014-02-28                 1              1
# 1    29258453508  29258453508 2014-02-27                 5              3
# 2    51750724947  51750724947 2014-02-24                 6              5
# 3    93274880719  93274880719 2014-02-24                11              6
# 4    51750724947  51750724947 2014-02-23                 6              5
#
#    Qty  Rate      Tax  total_amt Store_type        DOB Gender  city_code  \
# 0   -5  -772  405.300  -4265.300     e-Shop 1981-09-26      M        5.0
# 1   -5 -1497  785.925  -8270.925     e-Shop 1973-11-05      F        8.0
# 2   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
# 3   -3 -1363  429.345  -4518.345     e-Shop 1981-08-06      M        3.0
# 4   -2  -791  166.110  -1748.110   TeleShop 1992-07-27      M        8.0
#
#            prod_cat prod_subcat               Current Date   age
# ...

# %%
pd.to_numeric(Customer_Final["age"])
# Out:
# 0        39.0
# 1        47.0
# 2        28.0
# 3        39.0
# 4        28.0
#          ...
# 23048    48.0
# 23049    36.0
# 23050    44.0
# 23051    50.0
# 23052    38.0
# Name: age, Length: 23040, dtype: float64

# %%
Customer_Final.age
# Out:
# 0        39.0
# 1        47.0
# 2        28.0
# 3        39.0
# 4        28.0
#          ...
# 23048    48.0
# 23049    36.0
# 23050    44.0
# 23051    50.0
# 23052    38.0
# Name: age, Length: 23040, dtype: float64

# %%
Cust_25_35=Customer_Final[(Customer_Final['age']>=25) & (Customer_Final['age']<=35)]

# %%
Cust_25_35
# Out:
#       transaction_id      cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 2        51750724947  51750724947 2014-02-24                 6              5
# 4        51750724947  51750724947 2014-02-23                 6              5
# 11       25455265351  25455265351 2014-02-20                12              6
# 23       91116291703  91116291703 2014-02-20                 1              2
# 28       88853694830  88853694830 2014-02-20                 4              4
# ...              ...          ...        ...               ...            ...
# 23034    28972634039  28972634039 2011-01-25                 9              3
# 23035    42161597232  42161597232 2011-01-25                 3              1
# 23038    61812307223  61812307223 2011-01-25                 4              4
# 23042    49584040240  49584040240 2011-01-25                 5              3
# 23044    14787475597  14787475597 2011-01-25                 4              3
#
# ...

# %% [markdown]
# ## 11(a)

# %%
(Cust_25_35.groupby(["prod_cat"])["total_amt"].sum())[["Electronics","Books"]]
# Out:
# prod_cat
# Electronics    3942415.685
# Books          4391841.285
# Name: total_amt, dtype: float64

# %% [markdown]
# ## 11(b)

# %%
 #1st Jan, 2014 to 1st Mar, 2014

# %%
Cust_25_35[(Cust_25_35["tran_date"]>="2014-01-01") & (Cust_25_35["tran_date"]<="2014-03-01")].total_amt.sum()
# Out:
# 571808.77
